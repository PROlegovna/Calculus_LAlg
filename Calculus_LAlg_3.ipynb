# %% [markdown]
# ## Практическое задание

# %% [markdown]
# __1.__ Найдите собственные векторы и собственные значения для линейного оператора, заданного матрицей:
#
# $$A=\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}.$$
#
# __2.__ Дан оператор поворота на 180 градусов, задаваемый матрицей:
#
# $$A=\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}.$$
#
# Покажите, что __любой__ вектор считается для него собственным.
#
# __3.__ Пусть линейный оператор задан матрицей:
#
# $$A=\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}.$$
#
# Установите, считается ли вектор $x=(1,1)$ собственным вектором этого линейного оператора.

# %% [markdown]
# **4.** Пусть линейный оператор задан матрицей:
#
# $$A=\begin{pmatrix} 0 & 3 & 0\\ 3 & 0 & 0\\ 0 & 0 & 3 \end{pmatrix}.$$
#
# Установите, считается ли вектор $x=(3, -3, -4)$ собственным вектором этого линейного оператора.

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import *
from sympy.matrices import Matrix
from sympy import *
from sympy.solvers.solvers import solve

# %% [markdown]
# __1.__ Найдите собственные векторы и собственные значения для линейного оператора, заданного матрицей:
#
# $$A=\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}.$$

# %% [markdown]
# ![1.jpg](attachment:1.jpg)

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

plt.axis('scaled')
plt.xlim(-6, 6)
plt.ylim(-6, 6)

ax.arrow(0, 0, 6, 2, head_width=0.15, head_length=0.2, length_includes_head=True, facecolor='black')
ax.arrow(0, 0, -6, -1, head_width=0.15, head_length=0.2, length_includes_head=True, facecolor='black')
ax.annotate("e1", xy=(0.8, 0.3))
ax.annotate("e2", xy=(0.6, 1.0))

plt.show()

# %%
a = np.array([[-1, -6], [2, 6]])
w, v = np.linalg.eig(a)
 
print(f'Матрица A:\n{a}')
print(f'Собственные значения:\n{w}')
print(f'Собственные векторы:\n{v}')
# Out:
# Матрица A:
# [[-1 -6]
#  [ 2  6]]
# Собственные значения:
# [2. 3.]
# Собственные векторы:
# [[-0.89442719  0.83205029]
#  [ 0.4472136  -0.5547002 ]]

# %% [markdown]
# __2.__ Дан оператор поворота на 180 градусов, задаваемый матрицей:
#
# $$A=\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}.$$
#
# Покажите, что __любой__ вектор считается для него собственным.

# %% [markdown]
# ![2.jpg](attachment:2.jpg)

# %%
a = np.array([[-1, 0], [0, -1]])
w, v = np.linalg.eig(a)
 
print(f'Матрица A:\n{a}')
print(f'Собственные значения:\n{w}')
print(f'Собственные векторы:\n{v}')
# Out:
# Матрица A:
# [[-1  0]
#  [ 0 -1]]
# Собственные значения:
# [-1. -1.]
# Собственные векторы:
# [[1. 0.]
#  [0. 1.]]

# %%
x = np.array([[x1], [x2]])
print(f'x:\n{x}')
# Out:
# x:
# [[x1]
#  [x2]]

# %%
w * x
# Out:
# array([[-1.0*x1, -1.0*x1],
#        [-1.0*x2, -1.0*x2]], dtype=object)

# %%
print((a * x)[0], "=", (w * x)[0])
# Out:
# [-x1 0] = [-1.0*x1 -1.0*x1]

# %%
print((a * x)[1], "=", (w * x)[1])
# Out:
# [0 -x2] = [-1.0*x2 -1.0*x2]

# %%
x = Matrix([x1, x2])
x
# Out:
# Matrix([
# [x1],
# [x2]])

# %% [markdown]
# __3.__ Пусть линейный оператор задан матрицей:
#
# $$A=\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}.$$
#
# Установите, считается ли вектор $x=(1,1)$ собственным вектором этого линейного оператора.

# %% [markdown]
# ![3.jpg](attachment:3.jpg)

# %%
a = np.array([[1, 1], [-1, 3]])
w, v = np.linalg.eig(a)
 
print(f'Матрица A:\n{a}')
print(f'Собственные значения:\n{w}')
print(f'Собственные векторы:\n{v}')
# Out:
# Матрица A:
# [[ 1  1]
#  [-1  3]]
# Собственные значения:
# [2.00000002 1.99999998]
# Собственные векторы:
# [[ 0.70710677 -0.70710679]
#  [ 0.70710679 -0.70710677]]

# %% [markdown]
# Вектор  𝑥=(1,1) является собственным вектором линейного оператора, так как λ = 2

# %% [markdown]
# **4.** Пусть линейный оператор задан матрицей:
#
# $$A=\begin{pmatrix} 0 & 3 & 0\\ 3 & 0 & 0\\ 0 & 0 & 3 \end{pmatrix}.$$
#
# Установите, считается ли вектор $x=(3, -3, -4)$ собственным вектором этого линейного оператора.

# %% [markdown]
# ![4.jpg](attachment:4.jpg)

# %%
a = np.array([[0, 3, 0], [3, 0, 0], [0, 0, 3]])
w, v = np.linalg.eig(a)
 
print(f'Матрица A:\n{a}')
# Out:
# Матрица A:
# [[0 3 0]
#  [3 0 0]
#  [0 0 3]]

# %%
x = np.array([[3], [-3], [-4]])
print(f'Вектор:\n{x}')
# Out:
# Вектор:
# [[ 3]
#  [-3]
#  [-4]]

# %%
print(f'Собственные значения:\n{w}')
# Out:
# Собственные значения:
# [ 3. -3.  3.]

# %%
print(f'Собственные векторы:\n{v}')
# Out:
# Собственные векторы:
# [[ 0.70710678 -0.70710678  0.        ]
#  [ 0.70710678  0.70710678  0.        ]
#  [ 0.          0.          1.        ]]

# %%
M = a * x - w * x
M
# Out:
# array([[-9.00000000e+00,  1.80000000e+01, -9.00000000e+00],
#        [-1.77635684e-15, -9.00000000e+00,  9.00000000e+00],
#        [ 1.20000000e+01, -1.20000000e+01,  0.00000000e+00]])

# %% [markdown]
# Вектор  𝑥=(3,−3,−4)  не является собственным вектором линейного оператора
